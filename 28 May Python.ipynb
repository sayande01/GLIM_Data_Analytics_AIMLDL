# %%
import pandas as pd

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
df.head()
# Out:
#    Campaign ID       Campaign Name         Platform Start Date   End Date  \
# 0          1.0         Summer Sale       Google Ads        NaT 2023-06-10
# 1          2.0  New Product Launch     Facebook Ads        NaT 2023-06-15
# 2          3.0          Flash Deal    Instagram Ads        NaT 2023-06-20
# 3          4.0     Brand Awareness      YouTube Ads        NaT 2023-06-25
# 4          5.0     Email Promotion  Email Marketing        NaT 2023-06-30
#
#    Impressions  Clicks  Conversions  CVR (Conversion Rate)    Cost
# 0      10000.0   500.0         25.0                   0.05  1000.0
# 1       8000.0   400.0         20.0                   0.05   800.0
# 2      12000.0   600.0         30.0                   0.05     NaN
# 3      15000.0   700.0         35.0                   0.05  2000.0
# 4       5000.0     NaN         15.0                   0.06   500.0

# %%
df.tail()
# Out:
#     Campaign ID               Campaign Name           Platform Start Date  \
# 34         35.0           Webinar Promotion           Webinars        NaT
# 35         36.0         Video Streaming Ads  Video Advertising 2023-11-22
# 36         37.0         Podcast Sponsorship  Audio Advertising 2023-11-27
# 37         38.0  Search Engine Optimization     Organic Search        NaT
# 38         39.0    Social Media Influencers      Instagram Ads 2023-12-07
#
#      End Date  Impressions  Clicks  Conversions  CVR (Conversion Rate)    Cost
# 34 2023-11-27       5000.0   250.0         10.0                    NaN     NaN
# 35 2023-12-02      10000.0   600.0         30.0               0.050000  1000.0
# 36 2023-12-07       3000.0   150.0         10.0               0.060000   500.0
# 37 2023-12-12       8000.0   400.0         20.0                    NaN   800.0
# 38 2023-12-17      10000.0     NaN         16.0               0.052143   580.0

# %%
df.shape
# Out:
# (39, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Campaign ID            38 non-null     float64
#  1   Campaign Name          38 non-null     object
#  2   Platform               38 non-null     object
#  3   Start Date             22 non-null     datetime64[ns]
#  4   End Date               38 non-null     datetime64[ns]
#  5   Impressions            38 non-null     float64
#  6   Clicks                 32 non-null     float64
#  7   Conversions            38 non-null     float64
#  8   CVR (Conversion Rate)  32 non-null     float64
#  9   Cost                   35 non-null     float64
# dtypes: datetime64[ns](2), float64(6), object(2)
# memory usage: 3.2+ KB

# %%
df.isnull().sum()
# Out:
# Campaign ID               1
# Campaign Name             1
# Platform                  1
# Start Date               17
# End Date                  1
# Impressions               1
# Clicks                    7
# Conversions               1
# CVR (Conversion Rate)     7
# Cost                      4
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
#dropped null records
df.shape
# Out:
# (14, 10)

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
df.dropna(axis = 1, inplace = True)

# %%
df.shape
# Out:
# (39, 0)

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
# Fill null value  with a defined value
df.fillna(0, inplace = True)
# Out:
# C:\Users\sayan\AppData\Local\Temp\ipykernel_26296\2745988597.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df.fillna(0, inplace = True)

# %%
df.isnull().sum()
# Out:
# Campaign ID              0
# Campaign Name            0
# Platform                 0
# Start Date               0
# End Date                 0
# Impressions              0
# Clicks                   0
# Conversions              0
# CVR (Conversion Rate)    0
# Cost                     0
# dtype: int64

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
df.fillna({'Campaign Name' : 'New Campaign May 28', 'Clicks': 99999}, inplace = True)

# %%
df
# Out:
#     Campaign ID               Campaign Name                Platform  \
# 0           1.0                 Summer Sale              Google Ads
# 1           2.0          New Product Launch            Facebook Ads
# 2           3.0                  Flash Deal           Instagram Ads
# 3           4.0             Brand Awareness             YouTube Ads
# 4           5.0             Email Promotion         Email Marketing
# 5           6.0    Influencer Collaboration           Instagram Ads
# 6           7.0                  Search Ads              Google Ads
# 7           8.0        Social Media Contest            Facebook Ads
# 8           9.0                 Display Ads              Google Ads
# 9           NaN         New Campaign May 28                     NaN
# 10         11.0             Retargeting Ads            Facebook Ads
# 11         12.0           Sponsored Content            LinkedIn Ads
# 12         13.0          Mobile App Install      Mobile Advertising
# ...

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
# replace null values with mean value of the column
# Clicks(mean) = 506.25
df.fillna({'Clicks' : df['Clicks'].mean() }, inplace = True)

# %%
df
# Out:
#     Campaign ID               Campaign Name                Platform  \
# 0           1.0                 Summer Sale              Google Ads
# 1           2.0          New Product Launch            Facebook Ads
# 2           3.0                  Flash Deal           Instagram Ads
# 3           4.0             Brand Awareness             YouTube Ads
# 4           5.0             Email Promotion         Email Marketing
# 5           6.0    Influencer Collaboration           Instagram Ads
# 6           7.0                  Search Ads              Google Ads
# 7           8.0        Social Media Contest            Facebook Ads
# 8           9.0                 Display Ads              Google Ads
# 9           NaN                         NaN                     NaN
# 10         11.0             Retargeting Ads            Facebook Ads
# 11         12.0           Sponsored Content            LinkedIn Ads
# 12         13.0          Mobile App Install      Mobile Advertising
# ...

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
df.fillna({'Platform' : df['Platform'].mode()[0]}, inplace = True)

# %%
df
# Out:
#     Campaign ID               Campaign Name                Platform  \
# 0           1.0                 Summer Sale              Google Ads
# 1           2.0          New Product Launch            Facebook Ads
# 2           3.0                  Flash Deal           Instagram Ads
# 3           4.0             Brand Awareness             YouTube Ads
# 4           5.0             Email Promotion         Email Marketing
# 5           6.0    Influencer Collaboration           Instagram Ads
# 6           7.0                  Search Ads              Google Ads
# 7           8.0        Social Media Contest            Facebook Ads
# 8           9.0                 Display Ads              Google Ads
# 9           NaN                         NaN            Facebook Ads
# 10         11.0             Retargeting Ads            Facebook Ads
# 11         12.0           Sponsored Content            LinkedIn Ads
# 12         13.0          Mobile App Install      Mobile Advertising
# ...

# %%
df['Platform'].mode()
# Out:
# 0    Facebook Ads
# Name: Platform, dtype: object

# %%
df = pd.read_excel('DM impression.xlsx')
df
# Out:
#     Campaign ID               Campaign Name                Platform  \
# 0           1.0                 Summer Sale              Google Ads
# 1           2.0          New Product Launch            Facebook Ads
# 2           3.0                  Flash Deal           Instagram Ads
# 3           4.0             Brand Awareness             YouTube Ads
# 4           5.0             Email Promotion         Email Marketing
# 5           6.0    Influencer Collaboration           Instagram Ads
# 6           7.0                  Search Ads              Google Ads
# 7           8.0        Social Media Contest            Facebook Ads
# 8           9.0                 Display Ads              Google Ads
# 9           NaN                         NaN                     NaN
# 10         11.0             Retargeting Ads            Facebook Ads
# 11         12.0           Sponsored Content            LinkedIn Ads
# 12         13.0          Mobile App Install      Mobile Advertising
# ...

# %%
# Forward fill -> Replace value with previous rows values
df.ffill()
# Out:
#     Campaign ID               Campaign Name                Platform  \
# 0           1.0                 Summer Sale              Google Ads
# 1           2.0          New Product Launch            Facebook Ads
# 2           3.0                  Flash Deal           Instagram Ads
# 3           4.0             Brand Awareness             YouTube Ads
# 4           5.0             Email Promotion         Email Marketing
# 5           6.0    Influencer Collaboration           Instagram Ads
# 6           7.0                  Search Ads              Google Ads
# 7           8.0        Social Media Contest            Facebook Ads
# 8           9.0                 Display Ads              Google Ads
# 9           9.0                 Display Ads              Google Ads
# 10         11.0             Retargeting Ads            Facebook Ads
# 11         12.0           Sponsored Content            LinkedIn Ads
# 12         13.0          Mobile App Install      Mobile Advertising
# ...

# %%
df = pd.read_excel('DM impression.xlsx')

# %%
#Backward fill -> Replace null val with succedding rows values
df.bfill()
# Out:
#     Campaign ID               Campaign Name                Platform  \
# 0           1.0                 Summer Sale              Google Ads
# 1           2.0          New Product Launch            Facebook Ads
# 2           3.0                  Flash Deal           Instagram Ads
# 3           4.0             Brand Awareness             YouTube Ads
# 4           5.0             Email Promotion         Email Marketing
# 5           6.0    Influencer Collaboration           Instagram Ads
# 6           7.0                  Search Ads              Google Ads
# 7           8.0        Social Media Contest            Facebook Ads
# 8           9.0                 Display Ads              Google Ads
# 9          11.0             Retargeting Ads            Facebook Ads
# 10         11.0             Retargeting Ads            Facebook Ads
# 11         12.0           Sponsored Content            LinkedIn Ads
# 12         13.0          Mobile App Install      Mobile Advertising
# ...
